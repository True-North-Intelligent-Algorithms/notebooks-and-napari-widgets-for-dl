# %% [markdown]
# ## Make patches from labels
#
# Make a set of augmented patches from labels.
#
# The difference between labels and patches is:
#
# 1.  Labels are a set of images and annotated ground truths, generated manually, or automatically.  Labels can be different sizes.
# 2.  Patches are a set of images and annotated ground truths generated from labels.  They are usually cropped from labels to be all the same size.  They are often augmented.  1 label can be used to generate many patches.

# %%
from skimage.io import imread
from matplotlib import pyplot as plt
from tnia.deeplearning.dl_helper import quantile_normalization, get_label_paths
from tnia.plotting.plt_helper import imshow_multi2d
import numpy as np
import json
from glob import glob
import pandas as pd
import os
from pathlib import Path
from tnia.deeplearning.augmentation import uber_augmenter

data_path = r'../../data'
parent_path = os.path.join(data_path, 'ladybugs_series')
label_path = os.path.join(parent_path, 'labels')

# open the info file
json_name = os.path.join(label_path, 'info.json')
json_ = json.load(open(json_name))

# get number of inputs and number of ground truths for this problem
num_inputs = json_['num_inputs']
num_ground_truths = json_['num_truths']
print('num inputs: ', num_inputs)   
print('num ground truth: ', num_ground_truths)

image_label_paths, ground_truths_label_paths = get_label_paths(1, num_ground_truths, label_path)
print('image label paths',image_label_paths)
print("ground_truth_label_paths", ground_truths_label_paths[0])

# get list of tif files in image_label_path
tif_files = glob(str(os.path.join(image_label_paths[0], '*.tif')))
json_files = glob(str(os.path.join(image_label_paths[0], '*.json')))
print()
for tif_file in tif_files:
    print("tif_file: ", tif_file)

patch_path= os.path.join(parent_path, 'patches')

if not os.path.exists(patch_path):
    os.mkdir(patch_path)
axes = 'YXC'
sub_sample = 1
# Out:
# num inputs:  1
# num ground truth:  1
# image label paths [WindowsPath('C:/Users/bnort/work/ImageJ2022/tnia/notebooks-and-napari-widgets-for-dl/data/ladybugs_series/labels/input0')]
# ground_truth_label_paths C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\labels\ground truth0
#
# tif_file:  C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\labels\input0\14729569_21970798_0.tif
# tif_file:  C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\labels\input0\15081929_22523284_0.tif
# tif_file:  C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\labels\input0\8220954_10897041_0.tif

# %% [markdown]
# ## Optionally delete old patches
#
# If you previously generated patches, optionally manually delete them (otherwise the new patches will be added to the old set, which could be OK in some cases, but if you add labels and re-augment many times you may end up with a lot (thousands and thousands) of patches)

# %% [markdown]
# ##  Augment
#
# In this step we loop through all the labels, normalize them and augment each label to create patches.
#
# Normalization is always tricky.  We want to normalize based on the expected range in real images, which are often larger than training patches.
#
# Augmentation takes one label, crops it to the right size to use as input for the neural network, then applies transformations like stretch, mirror, rotate and brightness and color transformations.  This is done to increase the size of the training data.  Transformations are applied to one label to create many training patches.

# %%
patch_size = 512
number_patches = 50

# create a df to save the label names in 
df = pd.DataFrame(columns=['base_name', 'xstart', 'ystart', 'xend', 'yend'])  

for i in range(len(tif_files)):
    # User input set index of label

    # get tif name
    tif_name = os.path.basename(tif_files[i])
    print('tiff name is', tif_name)

    image = imread(str(image_label_paths[0]/ (tif_name)))

    image = image

    # read labels (there can be more than one class)
    labels = []
    for ground_truths_label_path in ground_truths_label_paths:
        label = imread(os.path.join(ground_truths_label_path / (tif_name)))
        labels.append(label)

    # show labels image 
    images_to_show=[]
    titles = []
    images_to_show.append(image)
    titles.append("image")

    for label in labels:
        images_to_show.append(label)
        titles.append("mask")

    fig = imshow_multi2d(images_to_show, titles, 1, len(images_to_show), width=20, height=10)
    
    image = quantile_normalization(image, quantile_low = .01, quantile_high=.998, clip = False).astype(np.float32)
    
    uber_augmenter(image, labels, Path(patch_path), 'grid', patch_size, number_patches, do_random_brightness_contrast = False, do_random_gamma=False)
    uber_augmenter(image, labels, Path(patch_path), 'grid', patch_size, number_patches, do_random_brightness_contrast = True, do_random_gamma=False)
    uber_augmenter(image, labels, Path(patch_path), 'grid', patch_size, number_patches, do_random_brightness_contrast = True, do_random_gamma=True)
    uber_augmenter(image, labels, Path(patch_path), 'grid', patch_size, number_patches, do_random_brightness_contrast = True, do_random_gamma=True, do_color_jitter = True)
# Out:
# tiff name is 14729569_21970798_0.tif
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_0.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_1.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_2.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_3.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_4.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_5.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_6.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_7.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_8.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_9.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_10.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_11.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_12.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_13.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_14.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_15.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_16.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_17.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_18.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_19.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_20.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_21.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_22.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_23.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_24.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_25.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_26.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_27.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_28.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_29.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_30.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_31.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_32.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_33.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_34.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_35.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_36.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_37.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_38.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_39.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_40.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_41.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_42.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_43.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_44.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_45.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_46.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_47.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_48.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_49.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_50.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_51.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_52.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_53.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_54.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_55.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_56.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_57.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_58.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_59.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_60.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_61.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_62.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_63.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_64.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_65.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_66.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_67.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_68.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_69.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_70.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_71.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_72.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_73.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_74.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_75.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_76.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_77.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_78.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_79.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_80.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_81.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_82.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_83.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_84.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_85.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_86.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_87.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_88.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_89.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_90.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_91.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_92.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_93.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_94.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_95.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_96.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_97.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_98.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_99.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\Users\bnort\miniconda3\envs\pytorch_and_SAM3\lib\site-packages\albumentations\augmentations\functional.py:907: RuntimeWarning: invalid value encountered in power
#   return np.power(img, gamma)
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_100.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_101.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_102.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_103.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_104.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_105.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_106.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_107.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_108.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_109.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_110.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_111.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_112.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_113.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_114.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_115.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_116.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_117.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_118.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_119.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_120.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_121.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_122.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_123.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_124.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_125.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_126.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_127.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_128.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_129.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_130.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_131.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_132.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_133.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_134.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_135.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_136.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_137.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_138.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_139.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_140.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_141.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_142.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_143.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\Users\bnort\miniconda3\envs\pytorch_and_SAM3\lib\site-packages\pydantic\main.py:328: UserWarning: Pydantic serializer warnings:
#   Expected `Union[float, tuple[float, float]]` but got `list` - serialized value may not be as expected
#   Expected `Union[float, tuple[float, float]]` but got `list` - serialized value may not be as expected
#   Expected `Union[float, tuple[float, float]]` but got `list` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_144.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_145.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_146.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_147.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_148.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_149.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_150.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_151.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_152.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_153.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_154.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_155.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_156.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_157.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_158.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_159.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_160.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_161.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_162.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_163.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_164.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# ...
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_497.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_498.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_499.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_500.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_501.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_502.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_503.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_504.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_505.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_506.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_507.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_508.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_509.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_510.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_511.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_512.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_513.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_514.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_515.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_516.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_517.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_518.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_519.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_520.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_521.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_522.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_523.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_524.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_525.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_526.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_527.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_528.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_529.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_530.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_531.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_532.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_533.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_534.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_535.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_536.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_537.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_538.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_539.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_540.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_541.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_542.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_543.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_544.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_545.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_546.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_547.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_548.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_549.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_550.tif is a low contrast image
#   imsave(label_name, label_aug[j])
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\augmentation.py:227: UserWarning: C:\Users\bnort\work\ImageJ2022\tnia\notebooks-and-napari-widgets-for-dl\data\ladybugs_series\patches\ground truth0\grid_551.tif is a low contrast image
#   imsave(label_name, label_aug[j])
